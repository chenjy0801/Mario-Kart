# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import pandas as pd

# %%
I = img.imread("C:/Users/FF14/Desktop/project/NeuralKart-master/itemss.png")

# %%
plt.imshow(I)
plt.show()

# %%
I.shape
# Out:
# (288, 432, 4)
